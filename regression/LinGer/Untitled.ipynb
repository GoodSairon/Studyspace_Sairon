# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv('student_scores.csv')
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
x, y = df['Hours'].values.reshape(-1, 1), df['Scores'].values
x, y
# Out:
# (array([[2.5],
#         [5.1],
#         [3.2],
#         [8.5],
#         [3.5],
#         [1.5],
#         [9.2],
#         [5.5],
#         [8.3],
#         [2.7],
#         [7.7],
#         [5.9],
#         [4.5],
#         [3.3],
#         [1.1],
#         [8.9],
#         [2.5],
#         [1.9],
#         [6.1],
#         [7.4],
#         [2.7],
#         [4.8],
#         [3.8],
#         [6.9],
#         [7.8]]),
#  array([21, 47, 27, 75, 30, 20, 88, 60, 81, 25, 85, 62, 41, 42, 17, 95, 30,
#         24, 67, 69, 30, 54, 35, 76, 86]))

# %%
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
x_new = np.random.uniform(0, 10, [10, 1])
x_new
# Out:
# array([[9.13609539],
#        [7.86924909],
#        [8.1492091 ],
#        [8.7481249 ],
#        [6.95095874],
#        [1.55741764],
#        [6.89343254],
#        [0.38043464],
#        [9.86755073],
#        [4.15476814]])

# %%
y_new = model.predict(x_new)
y_new
# Out:
# array([91.79634566, 79.41190531, 82.1487394 , 88.00362247, 70.4348794 ,
#        17.70868206, 69.87251456,  6.2027277 , 98.9469093 , 43.09986987])

# %%
plt.plot(x, y)
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.show()

# %%
plt.plot(x_new, y_new)
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.show()

# %%
cv = cross_val_score(model, x, y, cv=4)

# %%
cv
# Out:
# array([0.89132879, 0.94943331, 0.94260326, 0.92777661])
