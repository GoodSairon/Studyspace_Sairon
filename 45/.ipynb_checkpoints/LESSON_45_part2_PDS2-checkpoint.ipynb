# %%
import warnings
import itertools
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
y = sm.datasets.sunspots.load_pandas()
y = y.data
y['YEAR'] = pd.to_datetime(y['YEAR'], format='%Y')
y['SUNACTIVITY']
# Out:
# 0       5.0
# 1      11.0
# 2      16.0
# 3      23.0
# 4      36.0
#        ...
# 304    40.4
# 305    29.8
# 306    15.2
# 307     7.5
# 308     2.9
# Name: SUNACTIVITY, Length: 309, dtype: float64

# %%
y = sm.datasets.sunspots.load_pandas()
y = y.data
df = pd.DataFrame({'SUN':y['SUNACTIVITY'].values}, index=pd.to_datetime(y['YEAR'], format='%Y'))
df
y = df
#y.columns = [[1, 2]]
#y[1] = pd.to_datetime(y[1], format='%Y')
#y.index = y.iloc[:, 0]
#y = y.drop(y.iloc[:, 0])
#y
y
# Out:
#              SUN
# YEAR
# 1700-01-01   5.0
# 1701-01-01  11.0
# 1702-01-01  16.0
# 1703-01-01  23.0
# 1704-01-01  36.0
# ...          ...
# 2004-01-01  40.4
# 2005-01-01  29.8
# 2006-01-01  15.2
# 2007-01-01   7.5
# 2008-01-01   2.9
#
# [309 rows x 1 columns]

# %%
# 'MS' групування місячних даних
y = y['SUN'].resample('MS').mean()
# bfill значить, що потрібно використовувати значення до заповнення пропущених значень
y = y.fillna(y.bfill())
print(y)
# Out:
# YEAR
# 1700-01-01     5.0
# 1700-02-01    11.0
# 1700-03-01    11.0
# 1700-04-01    11.0
# 1700-05-01    11.0
#               ...
# 2007-09-01     2.9
# 2007-10-01     2.9
# 2007-11-01     2.9
# 2007-12-01     2.9
# 2008-01-01     2.9
# Freq: MS, Name: SUN, Length: 3697, dtype: float64

# %%
y.plot(figsize=(15, 6))
plt.show()

# %% [markdown]
# - p – порядок авторегресії (AR), який дозволяє додати попередні значення часового ряду. Цей параметр можна проілюструвати твердженням «завтра, ймовірно, буде тепло, якщо останні три дні було тепло».
# - d – порядок інтегрування (I; тобто порядок різниць вихідного часового ряду). Він додає в модель поняття різниці часових рядів (визначає кількість минулих часових точок, які потрібно відняти від поточного значення). Цей параметр ілюструє таке твердження: 'завтра, ймовірно, буде така сама температура, якщо різниця в температурі за останні три дні була дуже мала'.
# - q – порядок ковзного середнього (MA), який дозволяє встановити похибку моделі як лінійну комбінацію значень помилок, що спостерігалися раніше.

# %% [markdown]
# (p,d,q)(P,D,Q)s

# %%
# Визначення p, d і q у діапазоні 0-2
p = d = q = range(0, 2)
# Генеруємо різні комбінації p, q и q
pdq = list(itertools.product(p, d, q))
# Генеруємо комбінації різних сезонних параметрів p, q и q
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))] 
print('Приклади комбінацій параметрів для сезонних ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Приклади комбінацій параметрів для сезонних ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
warnings.filterwarnings("ignore") # Вимикаємо попередження
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
            order=param,
            seasonal_order=param_seasonal,
            enforce_stationarity=False,
            enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.57919D+00    |proj g|=  4.18678D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   4.187D-06   5.579D+00
#   F =   5.5791895208434656
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:41254.52731711658
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.58608D+00    |proj g|=  5.66121D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.22588D+00    |proj g|=  3.27758D-02
#
# At iterate   10    f=  5.13572D+00    |proj g|=  4.63746D-01
#
# At iterate   15    f=  5.01832D+00    |proj g|=  2.84828D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     17     22      1     0     0   2.153D-05   5.018D+00
#   F =   5.0183188879798859
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:37109.44985772327
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.58133D+00    |proj g|=  1.45975D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      1      3      1     0     0   4.579D-07   4.581D+00
#   F =   4.5813250865511170
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:33876.31768995896
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.44592D+00    |proj g|=  2.17796D-01
#  This problem is unconstrained.
# At iterate    5    f=  4.43349D+00    |proj g|=  3.63513D-02
#
# At iterate   10    f=  4.41633D+00    |proj g|=  1.06817D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.29883D+00    |proj g|=  8.16579D-05
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      3      6      1     0     0   5.596D-09   3.299D+00
#   F =   3.2988340165725885
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:24397.57871853772
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#  This problem is unconstrained.
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.28853D+00    |proj g|=  2.46217D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      2      5      1     0     0   4.672D-05   3.289D+00
#   F =   3.2885259101243789
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:24323.36057945966
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.19618D+00    |proj g|=  4.19030D-02
#  This problem is unconstrained.
# At iterate    5    f=  3.16978D+00    |proj g|=  2.57427D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      6      9      1     0     0   4.662D-06   3.170D+00
#   F =   3.1697822390527297
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:23445.369875555883
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.18692D+00    |proj g|=  4.43246D-02
#  This problem is unconstrained.
# At iterate    5    f=  3.15646D+00    |proj g|=  3.62523D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5      9     12      1     0     0   3.907D-05   3.156D+00
#   F =   3.1558418366071117
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:23344.294539872983
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.28937D+00    |proj g|=  3.73555D-05
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      1      3      1     0     0   6.947D-05   3.289D+00
#   F =   3.2893733063762665
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:24329.626227346114
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.16162D+00    |proj g|=  3.77710D-01
#  This problem is unconstrained.
# At iterate    5    f=  3.36136D+00    |proj g|=  4.05811D-01
#
# At iterate   10    f=  3.29314D+00    |proj g|=  2.24502D-02
#
# At iterate   15    f=  3.28860D+00    |proj g|=  1.76612D-03
#
# At iterate   20    f=  3.28846D+00    |proj g|=  2.45037D-02
#
# At iterate   25    f=  3.28773D+00    |proj g|=  2.09977D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     29     39      1     0     0   9.298D-06   3.288D+00
#   F =   3.2877112566861233
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:24319.337031937197

# %%
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(1, 0, 1), 
                                seasonal_order=(1, 1, 1, 12), 
                                enforce_stationarity=False, 
                                enforce_invertibility=False)
results = mod.fit()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.47483D+00    |proj g|=  6.55041D-01
#  This problem is unconstrained.
# At iterate    5    f=  3.27906D+00    |proj g|=  1.14553D-02
#   ys=-6.827E-02  -gs= 6.534E-03 BFGS update SKIPPED
#
# At iterate   10    f=  3.17642D+00    |proj g|=  2.75074D-01
#
# At iterate   15    f=  3.17400D+00    |proj g|=  2.90597D-02
#
# At iterate   20    f=  3.16375D+00    |proj g|=  1.82157D-02
#
# At iterate   25    f=  3.16372D+00    |proj g|=  1.43113D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     26     42      1     1     0   4.614D-06   3.164D+00
#   F =   3.1637210347128475
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL

# %%
results

# %%
print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9732      0.009    107.437      0.000       0.955       0.991
# ma.L1          0.0133      0.110      0.120      0.904      -0.203       0.229
# ar.S.L12       0.5480      0.007     76.845      0.000       0.534       0.562
# ma.S.L12      -1.0000      8.661     -0.115      0.908     -17.976      15.976
# sigma2        33.6442    291.607      0.115      0.908    -537.895     605.183
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
pred = results.get_prediction(start=pd.to_datetime('2000-01-01'), dynamic=False)
pred_ci = pred.conf_int()

# %%
ax = y['1900':].plot(label='Відомі')
pred.predicted_mean.plot(ax=ax, label='Прогноз на один крок', alpha=.7)
ax.fill_between(pred_ci.index,
pred_ci.iloc[:, 0],
pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('SUN')
plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2000-01-01':] # Обчислюємо середню квадртичну похибку
mse = ((y_forecasted - y_truth) ** 2).mean()
print('Середня квадратна похибка прогнозів = {}'.format(round(mse, 2)))
# Out:
# Середня квадратна похибка прогнозів = 19.65

# %%
pred_dynamic = results.get_prediction(start=pd.to_datetime('2000-01-01'), dynamic=True, full_results=True)
pred_dynamic_ci = pred_dynamic.conf_int()

# %%
ax = y['1990':].plot(label='Відомі', figsize=(20, 15))
pred_dynamic.predicted_mean.plot(label='Динамічний прогноз', ax=ax)
ax.fill_between(pred_dynamic_ci.index,
pred_dynamic_ci.iloc[:, 0],
pred_dynamic_ci.iloc[:, 1], color='k', alpha=.25)
ax.fill_betweenx(ax.get_ylim(), pd.to_datetime('2000-01-01'), y.index[-1],
alpha=.1, zorder=-1)
ax.set_xlabel('Date')
ax.set_ylabel('SUN')
plt.legend()
plt.show()

# %%
# Отримуємо прогноз на 50 кроків у перед
pred_uc = results.get_forecast(steps=500)
# Отримуємо інтервал прогнозу
pred_ci = pred_uc.conf_int()

# %%
ax = y.plot(label='Відомі', figsize=(20, 15))
pred_uc.predicted_mean.plot(ax=ax, label='Прогноз')
ax.fill_between(pred_ci.index,
pred_ci.iloc[:, 0],
pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('SUN')
plt.legend()
plt.show()
